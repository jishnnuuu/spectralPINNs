# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import time

# Use high precision for stability (VERY important for spectral methods)
torch.set_default_dtype(torch.float64)

# %%
def chebyshev_cgl(N):
    """
    Generate Chebyshev-Gauss-Lobatto points in [-1,1]
    
    N = number of intervals
    returns N+1 points
    """
    j = torch.arange(0, N+1)
    x = torch.cos(torch.pi * j / N)
    return x

# %%
def chebyshev_diff_matrix(N):
    """
    Build differentiation matrix D such that:
    u_x ≈ D u
    """
    x = chebyshev_cgl(N)
    
    c = torch.ones(N+1)
    c[0] = 2.0
    c[-1] = 2.0
    
    X = x.unsqueeze(0)
    dX = X.T - X
    
    C = c.unsqueeze(0)
    C_ratio = C.T / C
    
    i = torch.arange(N+1)
    sign = (-1.0) ** (i.unsqueeze(0) + i.unsqueeze(1))
    
    # avoid division by zero
    dX = dX + torch.eye(N+1)
    
    D = C_ratio * sign / dX
    
    # fix diagonal entries
    D = D - torch.diag(torch.sum(D, dim=1))
    
    return x, D

# %%
def build_A(D, bc_weight=1.0):
    """
    Build full operator A such that:
    r = A u - f
    """
    
    # second derivative
    D2 = D @ D
    
    # PDE part: -u''
    A_pde = -D2
    
    # Boundary conditions
    Np1 = D.shape[0]
    A_bc = torch.zeros(2, Np1)
    
    A_bc[0, 0] = bc_weight       # u(-1)
    A_bc[1, -1] = bc_weight      # u(1)
    
    # Combine
    A = torch.cat([A_pde, A_bc], dim=0)
    
    return A

# %%
def chebyshev_basis(x, K):
    """
    Build basis matrix Phi
    
    Phi[i,k] = T_k(x_i)
    """
    
    theta = torch.arccos(x)
    k = torch.arange(0, K)
    
    Phi = torch.cos(theta.unsqueeze(1) * k.unsqueeze(0))
    
    return Phi

# %%
import torch.nn as nn

class CoeffNet(nn.Module):
    def __init__(self, K):
        super().__init__()
        
        self.net = nn.Sequential(
            nn.Linear(1, 8),
            nn.Tanh(),
            nn.Linear(8, 8),
            nn.Tanh(),
            nn.Linear(8, K)
        )
    
    def forward(self):
        # dummy input (we just want coefficients)
        x = torch.ones(1, 1)
        return self.net(x).squeeze()

# %%
def build_B(model):
    """
    Build Jacobian:
    B = dc/dθ
    
    Shape:
    (K, P)
    """
    
    c = model()
    K = c.shape[0]
    
    params = list(model.parameters())
    P = sum(p.numel() for p in params)
    
    B = torch.zeros(K, P)
    
    for k in range(K):
        model.zero_grad()
        c[k].backward(retain_graph=True)
        
        grads = []
        for p in params:
            grads.append(p.grad.view(-1))
        
        B[k] = torch.cat(grads)
    
    return B

# %%
def compute_residual(model, A, Phi, f):
    """
    Compute:
    r = A u - f
    """
    
    c = model()
    u = Phi @ c
    
    r = A @ u - f
    
    return r, u, c

# %%
# Problem setup

N = 20
K = 20

# Grid + differentiation
x, D = chebyshev_diff_matrix(N)

# Build operator A
A = build_A(D, bc_weight=10.0)

# Basis
Phi = chebyshev_basis(x, K)

# RHS f (example)
f = (torch.pi**2) * torch.sin(torch.pi * x)

# Extend f to match A (important!)
f = torch.cat([f, torch.zeros(2)])

model_smw = CoeffNet(K)

# %% [markdown]
# # Method 1: Direct Gauss–Newton using SMW Identity
#
# We solve:
#
#     (J^T J + μI) Δθ = -J^T r
#
# Using structure:
#
#     J = A Φ B
#
# So:
#
#     J^T J = B^T G B
#     G = Φ^T A^T A Φ
#
# Instead of solving:
#
#     (B^T G B + μI)
#
# we apply SMW:
#
#     (μI + B^T G B)^{-1}
#     = (1/μ)[I - B^T (μ G^{-1} + B B^T)^{-1} B]
#
# Final update:
#
#     Δθ = -(1/μ)[I - B^T (μ G^{-1} + B B^T)^{-1} B] B^T Φ^T A^T r
#
# Goal of this section:
# - Implement this formula step-by-step
# - Keep everything explicit and understandable

# %% [markdown]
# # Method 1 with HODLR
#
# We compute:
#
#     G = Φ^T A^T A Φ
#
# But we DO NOT use dense multiplication.
#
# Instead:
# - Use HODLR for A v
# - Compute A Φ column-by-column
#
# Pipeline:
#
# 1. For each basis column Φ_k:
#        compute A Φ_k using HODLR
#
# 2. Stack results → AΦ
#
# 3. Compute:
#        G = (AΦ)^T (AΦ)
#
# This avoids O(N^2 K) cost and uses fast matvec.

# %%
class RectangularHODLR:
    def __init__(self, n_rows, n_cols, block_fn, p=8, max_level=4, leaf_size=64):
        self.n_rows = n_rows
        self.n_cols = n_cols
        self.block_fn = block_fn
        self.p = p
        self.max_level = max_level
        self.leaf_size = leaf_size
        
        self.blocks = []
        self._build(0, self.n_rows, 0, self.n_cols, level=0)

    def _low_rank_approx(self, r0, r1, c0, c1):
        submat = self.block_fn(np.arange(r0, r1), np.arange(c0, c1))
        
        # SVD-based low rank
        U, S, Vt = np.linalg.svd(submat, full_matrices=False)
        
        k = min(self.p, len(S))
        U_k = U[:, :k]
        S_k = np.diag(S[:k])
        V_k = Vt[:k, :]
        
        return U_k, S_k, V_k

    def _build(self, r0, r1, c0, c1, level):
        is_far = (r1 <= c0) or (c1 <= r0)

        if is_far and level > 0:
            U, S, V = self._low_rank_approx(r0, r1, c0, c1)
            self.blocks.append(('lowrank', (r0, r1), (c0, c1), U, S, V))

        elif level >= self.max_level or (r1 - r0) <= self.leaf_size:
            mat = self.block_fn(np.arange(r0, r1), np.arange(c0, c1))
            self.blocks.append(('dense', (r0, r1), (c0, c1), mat))

        else:
            rmid = (r0 + r1) // 2
            cmid = (c0 + c1) // 2

            self._build(r0, rmid, c0, cmid, level + 1)
            self._build(r0, rmid, cmid, c1, level + 1)
            self._build(rmid, r1, c0, cmid, level + 1)
            self._build(rmid, r1, cmid, c1, level + 1)

    def matvec(self, v):
        y = np.zeros(self.n_rows)

        for kind, r_range, c_range, *data in self.blocks:
            r0, r1 = r_range
            c0, c1 = c_range

            if kind == 'dense':
                y[r0:r1] += data[0] @ v[c0:c1]
            else:
                U, S, V = data
                y[r0:r1] += U @ (S @ (V @ v[c0:c1]))

        return y

# %%
# Convert A → numpy for HODLR
A_np = A.detach().cpu().numpy()

def A_block(row_idx, col_idx):
    return A_np[np.ix_(row_idx, col_idx)]

# Build HODLR
H = RectangularHODLR(
    n_rows=A.shape[0],
    n_cols=A.shape[1],
    block_fn=A_block,
    p=16,
    max_level=4
)

# %%
def hodlr_matvec(H, v):
    """
    Compute A v using HODLR
    
    Input:
        v (torch) shape: (N+1,)
    
    Output:
        y (torch) shape: (N+3,)
    """
    
    v_np = v.detach().cpu().numpy()
    y_np = H.matvec(v_np)
    
    return torch.from_numpy(y_np)

# %%
def compute_A_Phi_hodlr(H, Phi):
    """
    Compute AΦ using HODLR matvec
    
    Inputs:
        H   : HODLR object (represents A)
        Phi : (N+1, K)
    
    Output:
        APhi : (N+3, K)
    """
    
    K = Phi.shape[1]
    APhi_cols = []
    
    for k in range(K):
        phi_k = Phi[:, k]                 # (N+1,)
        
        # Apply A using HODLR
        A_phi_k = hodlr_matvec(H, phi_k)  # (N+3,)
        
        APhi_cols.append(A_phi_k)
    
    APhi = torch.stack(APhi_cols, dim=1)  # (N+3, K)
    
    return APhi

# %%
def compute_G_from_APhi(APhi):
    """
    Compute:
        G = (AΦ)^T (AΦ)
    
    Input:
        APhi : (N+3, K)
    
    Output:
        G : (K, K)
    """
    
    G = APhi.T @ APhi
    
    return G

# %%
def hodlr_matvec_transpose(H, v):
    """
    Compute y = A^T v using HODLR
    
    Input:
        v : (N+3,)
    
    Output:
        y : (N+1,)
    """
    
    v_np = v.detach().cpu().numpy()
    y = np.zeros(H.n_cols)
    
    for kind, r_range, c_range, *data in H.blocks:
        r0, r1 = r_range
        c0, c1 = c_range
        
        if kind == 'dense':
            mat = data[0]
            y[c0:c1] += mat.T @ v_np[r0:r1]
        
        else:
            U, S, V = data
            # (U S V)^T = V^T S U^T
            y[c0:c1] += V.T @ (S @ (U.T @ v_np[r0:r1]))
    
    return torch.from_numpy(y)

# %%
def compute_rhs_hodlr(H, Phi, B, r):
    """
    Compute:
        g = B^T Φ^T A^T r
    
    Inputs:
        H   : HODLR (represents A)
        Phi : (N+1, K)
        B   : (K, P)
        r   : (N+3,)
    
    Output:
        g : (P,)
    """
    
    # Step 1: A^T r
    At_r = hodlr_matvec_transpose(H, r)   # (N+1,)
    
    # Step 2: Φ^T (A^T r)
    PhiT_At_r = Phi.T @ At_r              # (K,)
    
    # Step 3: B^T (...)
    g = B.T @ PhiT_At_r                  # (P,)
    
    return g

# %%
model = model_smw

B = build_B(model)
r, _, _ = compute_residual(model, A, Phi, f)

g = compute_rhs_hodlr(H, Phi, B, r)

print(g.shape)
# Out:
# torch.Size([268])

# %%
def solve_smw(G, B, g, mu):
    """
    Solve using SMW:

    Δθ = -(1/μ)[I - B^T (μ G^{-1} + B B^T)^{-1} B] g

    Inputs:
        G : (K, K)
        B : (K, P)
        g : (P,)
        mu: scalar

    Output:
        delta_theta : (P,)
    """
    G = G + 1e-3 * torch.eye(G.shape[0])  # regularization for stability
    
    # Step 1: G^{-1}
    G_inv = torch.linalg.inv(G)   # (K, K)
    
    # Step 2: BB^T
    BBt = B @ B.T                # (K, K)
    
    # Step 3: Small system
    M_small = mu * G_inv + BBt   # (K, K)
    
    M_small_inv = torch.linalg.inv(M_small)
    
    # Step 4: B g
    Bg = B @ g                   # (K,)
    
    # Step 5: Middle term
    middle = M_small_inv @ Bg    # (K,)
    
    # Step 6: B^T (...)
    B_middle = B.T @ middle      # (P,)
    
    # Step 7: Final SMW formula
    delta_theta = -(1.0 / mu) * (g - B_middle)
    
    return delta_theta

# %%
def apply_update(model, delta_theta, lr=0.1):
    """
    Update NN parameters:
        θ ← θ + lr * Δθ
    """
    
    params = list(model.parameters())
    
    idx = 0
    for p in params:
        numel = p.numel()
        
        update = delta_theta[idx:idx+numel].view_as(p)
        p.data += lr * update
        
        idx += numel

# %%
def train_smw_hodlr(model, H, Phi, A, f, steps=20, lam=1e-3):
    
    losses = []
    
    for i in range(steps):
        
        # Step 1: Build B
        B = build_B(model)   # (K, P)
        
        # Step 2: Residual
        r, u, c = compute_residual(model, A, Phi, f)
        
        loss = torch.norm(r)
        losses.append(loss.item())
        
        print(f"[SMW-HODLR] Iter {i}, Loss: {loss.item():.4e}")
        
        # Step 3: Compute AΦ (HODLR)
        APhi = compute_A_Phi_hodlr(H, Phi)
        
        # Step 4: Compute G
        G = compute_G_from_APhi(APhi)
        
        # Step 5: Compute RHS g
        g = compute_rhs_hodlr(H, Phi, B, r)
        
        # Step 6: Compute μ
        mu = lam * torch.max(torch.diag(G))
        mu = lam
        
        # Step 7: Solve SMW
        delta_theta = solve_smw(G, B, g, mu)
        
        # Step 8: Update
        apply_update(model, delta_theta)
    
    return losses

# %%
# Fresh model
model_smw = CoeffNet(K)

losses = train_smw_hodlr(
    model_smw,
    H,
    Phi,
    A,
    f,
    steps=300
)
# Out:
# [SMW-HODLR] Iter 0, Loss: 1.6910e+04
# [SMW-HODLR] Iter 1, Loss: 1.5271e+04
# [SMW-HODLR] Iter 2, Loss: 1.3776e+04
# [SMW-HODLR] Iter 3, Loss: 1.2414e+04
# [SMW-HODLR] Iter 4, Loss: 1.1176e+04
# [SMW-HODLR] Iter 5, Loss: 1.0054e+04
# [SMW-HODLR] Iter 6, Loss: 9.0376e+03
# [SMW-HODLR] Iter 7, Loss: 8.1216e+03
# [SMW-HODLR] Iter 8, Loss: 7.2961e+03
# [SMW-HODLR] Iter 9, Loss: 6.5562e+03
# [SMW-HODLR] Iter 10, Loss: 5.8919e+03
# [SMW-HODLR] Iter 11, Loss: 5.2937e+03
# [SMW-HODLR] Iter 12, Loss: 4.7577e+03
# [SMW-HODLR] Iter 13, Loss: 4.2758e+03
# [SMW-HODLR] Iter 14, Loss: 3.8437e+03
# [SMW-HODLR] Iter 15, Loss: 3.4552e+03
# [SMW-HODLR] Iter 16, Loss: 3.1053e+03
# [SMW-HODLR] Iter 17, Loss: 2.7926e+03
# [SMW-HODLR] Iter 18, Loss: 2.5108e+03
# [SMW-HODLR] Iter 19, Loss: 2.2575e+03
# [SMW-HODLR] Iter 20, Loss: 2.0308e+03
# [SMW-HODLR] Iter 21, Loss: 1.8264e+03
# [SMW-HODLR] Iter 22, Loss: 1.6429e+03
# [SMW-HODLR] Iter 23, Loss: 1.4785e+03
# [SMW-HODLR] Iter 24, Loss: 1.3302e+03
# [SMW-HODLR] Iter 25, Loss: 1.1967e+03
# [SMW-HODLR] Iter 26, Loss: 1.0767e+03
# [SMW-HODLR] Iter 27, Loss: 9.6879e+02
# [SMW-HODLR] Iter 28, Loss: 8.7183e+02
# [SMW-HODLR] Iter 29, Loss: 7.8461e+02
# [SMW-HODLR] Iter 30, Loss: 7.0601e+02
# [SMW-HODLR] Iter 31, Loss: 6.3543e+02
# [SMW-HODLR] Iter 32, Loss: 5.7167e+02
# [SMW-HODLR] Iter 33, Loss: 5.1453e+02
# [SMW-HODLR] Iter 34, Loss: 4.6309e+02
# [SMW-HODLR] Iter 35, Loss: 4.1676e+02
# [SMW-HODLR] Iter 36, Loss: 3.7490e+02
# [SMW-HODLR] Iter 37, Loss: 3.3725e+02
# [SMW-HODLR] Iter 38, Loss: 3.0357e+02
# [SMW-HODLR] Iter 39, Loss: 2.7327e+02
# [SMW-HODLR] Iter 40, Loss: 2.4590e+02
# [SMW-HODLR] Iter 41, Loss: 2.2133e+02
# [SMW-HODLR] Iter 42, Loss: 1.9919e+02
# [SMW-HODLR] Iter 43, Loss: 1.7918e+02
# [SMW-HODLR] Iter 44, Loss: 1.6126e+02
# [SMW-HODLR] Iter 45, Loss: 1.4515e+02
# [SMW-HODLR] Iter 46, Loss: 1.3063e+02
# [SMW-HODLR] Iter 47, Loss: 1.1760e+02
# [SMW-HODLR] Iter 48, Loss: 1.0584e+02
# [SMW-HODLR] Iter 49, Loss: 9.5255e+01
# [SMW-HODLR] Iter 50, Loss: 8.5708e+01
# [SMW-HODLR] Iter 51, Loss: 7.7135e+01
# [SMW-HODLR] Iter 52, Loss: 6.9434e+01
# [SMW-HODLR] Iter 53, Loss: 6.2494e+01
# [SMW-HODLR] Iter 54, Loss: 5.6236e+01
# [SMW-HODLR] Iter 55, Loss: 5.0618e+01
# [SMW-HODLR] Iter 56, Loss: 4.5563e+01
# [SMW-HODLR] Iter 57, Loss: 4.1007e+01
# [SMW-HODLR] Iter 58, Loss: 3.6909e+01
# [SMW-HODLR] Iter 59, Loss: 3.3222e+01
# [SMW-HODLR] Iter 60, Loss: 2.9897e+01
# [SMW-HODLR] Iter 61, Loss: 2.6910e+01
# [SMW-HODLR] Iter 62, Loss: 2.4215e+01
# [SMW-HODLR] Iter 63, Loss: 2.1791e+01
# [SMW-HODLR] Iter 64, Loss: 1.9612e+01
# [SMW-HODLR] Iter 65, Loss: 1.7655e+01
# [SMW-HODLR] Iter 66, Loss: 1.5889e+01
# [SMW-HODLR] Iter 67, Loss: 1.4301e+01
# [SMW-HODLR] Iter 68, Loss: 1.2872e+01
# [SMW-HODLR] Iter 69, Loss: 1.1588e+01
# [SMW-HODLR] Iter 70, Loss: 1.0432e+01
# [SMW-HODLR] Iter 71, Loss: 9.3911e+00
# [SMW-HODLR] Iter 72, Loss: 8.4515e+00
# [SMW-HODLR] Iter 73, Loss: 7.6078e+00
# [SMW-HODLR] Iter 74, Loss: 6.8468e+00
# [SMW-HODLR] Iter 75, Loss: 6.1634e+00
# [SMW-HODLR] Iter 76, Loss: 5.5477e+00
# [SMW-HODLR] Iter 77, Loss: 4.9937e+00
# [SMW-HODLR] Iter 78, Loss: 4.4944e+00
# [SMW-HODLR] Iter 79, Loss: 4.0456e+00
# [SMW-HODLR] Iter 80, Loss: 3.6409e+00
# [SMW-HODLR] Iter 81, Loss: 3.2770e+00
# [SMW-HODLR] Iter 82, Loss: 2.9486e+00
# [SMW-HODLR] Iter 83, Loss: 2.6546e+00
# [SMW-HODLR] Iter 84, Loss: 2.3885e+00
# [SMW-HODLR] Iter 85, Loss: 2.1499e+00
# [SMW-HODLR] Iter 86, Loss: 1.9353e+00
# [SMW-HODLR] Iter 87, Loss: 1.7424e+00
# [SMW-HODLR] Iter 88, Loss: 1.5683e+00
# [SMW-HODLR] Iter 89, Loss: 1.4112e+00
# [SMW-HODLR] Iter 90, Loss: 1.2701e+00
# [SMW-HODLR] Iter 91, Loss: 1.1428e+00
# [SMW-HODLR] Iter 92, Loss: 1.0284e+00
# [SMW-HODLR] Iter 93, Loss: 9.2542e-01
# [SMW-HODLR] Iter 94, Loss: 8.3274e-01
# [SMW-HODLR] Iter 95, Loss: 7.4954e-01
# [SMW-HODLR] Iter 96, Loss: 6.7450e-01
# [SMW-HODLR] Iter 97, Loss: 6.0702e-01
# [SMW-HODLR] Iter 98, Loss: 5.4652e-01
# [SMW-HODLR] Iter 99, Loss: 4.9191e-01
# [SMW-HODLR] Iter 100, Loss: 4.4268e-01
# [SMW-HODLR] Iter 101, Loss: 3.9831e-01
# [SMW-HODLR] Iter 102, Loss: 3.5844e-01
# [SMW-HODLR] Iter 103, Loss: 3.2254e-01
# [SMW-HODLR] Iter 104, Loss: 2.9031e-01
# [SMW-HODLR] Iter 105, Loss: 2.6129e-01
# [SMW-HODLR] Iter 106, Loss: 2.3528e-01
# [SMW-HODLR] Iter 107, Loss: 2.1179e-01
# [SMW-HODLR] Iter 108, Loss: 1.9061e-01
# [SMW-HODLR] Iter 109, Loss: 1.7153e-01
# [SMW-HODLR] Iter 110, Loss: 1.5441e-01
# [SMW-HODLR] Iter 111, Loss: 1.3898e-01
# [SMW-HODLR] Iter 112, Loss: 1.2511e-01
# [SMW-HODLR] Iter 113, Loss: 1.1263e-01
# [SMW-HODLR] Iter 114, Loss: 1.0137e-01
# [SMW-HODLR] Iter 115, Loss: 9.1230e-02
# [SMW-HODLR] Iter 116, Loss: 8.2139e-02
# [SMW-HODLR] Iter 117, Loss: 7.3924e-02
# [SMW-HODLR] Iter 118, Loss: 6.6530e-02
# [SMW-HODLR] Iter 119, Loss: 5.9898e-02
# [SMW-HODLR] Iter 120, Loss: 5.3910e-02
# [SMW-HODLR] Iter 121, Loss: 4.8522e-02
# [SMW-HODLR] Iter 122, Loss: 4.3674e-02
# [SMW-HODLR] Iter 123, Loss: 3.9319e-02
# [SMW-HODLR] Iter 124, Loss: 3.5396e-02
# [SMW-HODLR] Iter 125, Loss: 3.1862e-02
# [SMW-HODLR] Iter 126, Loss: 2.8683e-02
# [SMW-HODLR] Iter 127, Loss: 2.5818e-02
# [SMW-HODLR] Iter 128, Loss: 2.3235e-02
# [SMW-HODLR] Iter 129, Loss: 2.0915e-02
# [SMW-HODLR] Iter 130, Loss: 1.8827e-02
# [SMW-HODLR] Iter 131, Loss: 1.6939e-02
# [SMW-HODLR] Iter 132, Loss: 1.5245e-02
# [SMW-HODLR] Iter 133, Loss: 1.3719e-02
# [SMW-HODLR] Iter 134, Loss: 1.2347e-02
# [SMW-HODLR] Iter 135, Loss: 1.1112e-02
# [SMW-HODLR] Iter 136, Loss: 1.0000e-02
# [SMW-HODLR] Iter 137, Loss: 9.0003e-03
# [SMW-HODLR] Iter 138, Loss: 8.0994e-03
# [SMW-HODLR] Iter 139, Loss: 7.2931e-03
# [SMW-HODLR] Iter 140, Loss: 6.5645e-03
# [SMW-HODLR] Iter 141, Loss: 5.9097e-03
# [SMW-HODLR] Iter 142, Loss: 5.3189e-03
# [SMW-HODLR] Iter 143, Loss: 4.7868e-03
# [SMW-HODLR] Iter 144, Loss: 4.3073e-03
# [SMW-HODLR] Iter 145, Loss: 3.8761e-03
# [SMW-HODLR] Iter 146, Loss: 3.4889e-03
# [SMW-HODLR] Iter 147, Loss: 3.1402e-03
# [SMW-HODLR] Iter 148, Loss: 2.8264e-03
# [SMW-HODLR] Iter 149, Loss: 2.5439e-03
# [SMW-HODLR] Iter 150, Loss: 2.2898e-03
# [SMW-HODLR] Iter 151, Loss: 2.0611e-03
# [SMW-HODLR] Iter 152, Loss: 1.8556e-03
# [SMW-HODLR] Iter 153, Loss: 1.6697e-03
# [SMW-HODLR] Iter 154, Loss: 1.5027e-03
# [SMW-HODLR] Iter 155, Loss: 1.3524e-03
# [SMW-HODLR] Iter 156, Loss: 1.2170e-03
# [SMW-HODLR] Iter 157, Loss: 1.0952e-03
# [SMW-HODLR] Iter 158, Loss: 9.8581e-04
# [SMW-HODLR] Iter 159, Loss: 8.8728e-04
# [SMW-HODLR] Iter 160, Loss: 7.9854e-04
# [SMW-HODLR] Iter 161, Loss: 7.1871e-04
# [SMW-HODLR] Iter 162, Loss: 6.4693e-04
# [SMW-HODLR] Iter 163, Loss: 5.8213e-04
# [SMW-HODLR] Iter 164, Loss: 5.2395e-04
# [SMW-HODLR] Iter 165, Loss: 4.7156e-04
# [SMW-HODLR] Iter 166, Loss: 4.2450e-04
# [SMW-HODLR] Iter 167, Loss: 3.8202e-04
# [SMW-HODLR] Iter 168, Loss: 3.4373e-04
# [SMW-HODLR] Iter 169, Loss: 3.0940e-04
# [SMW-HODLR] Iter 170, Loss: 2.7845e-04
# [SMW-HODLR] Iter 171, Loss: 2.5064e-04
# [SMW-HODLR] Iter 172, Loss: 2.2552e-04
# [SMW-HODLR] Iter 173, Loss: 2.0297e-04
# [SMW-HODLR] Iter 174, Loss: 1.8276e-04
# [SMW-HODLR] Iter 175, Loss: 1.6449e-04
# [SMW-HODLR] Iter 176, Loss: 1.4802e-04
# [SMW-HODLR] Iter 177, Loss: 1.3324e-04
# [SMW-HODLR] Iter 178, Loss: 1.1993e-04
# [SMW-HODLR] Iter 179, Loss: 1.0795e-04
# [SMW-HODLR] Iter 180, Loss: 9.7174e-05
# [SMW-HODLR] Iter 181, Loss: 8.7497e-05
# [SMW-HODLR] Iter 182, Loss: 7.8754e-05
# [SMW-HODLR] Iter 183, Loss: 7.0862e-05
# [SMW-HODLR] Iter 184, Loss: 6.3776e-05
# [SMW-HODLR] Iter 185, Loss: 5.7388e-05
# [SMW-HODLR] Iter 186, Loss: 5.1648e-05
# [SMW-HODLR] Iter 187, Loss: 4.6485e-05
# [SMW-HODLR] Iter 188, Loss: 4.1849e-05
# [SMW-HODLR] Iter 189, Loss: 3.7673e-05
# [SMW-HODLR] Iter 190, Loss: 3.3899e-05
# [SMW-HODLR] Iter 191, Loss: 3.0514e-05
# [SMW-HODLR] Iter 192, Loss: 2.7469e-05
# [SMW-HODLR] Iter 193, Loss: 2.4724e-05
# [SMW-HODLR] Iter 194, Loss: 2.2253e-05
# [SMW-HODLR] Iter 195, Loss: 2.0029e-05
# [SMW-HODLR] Iter 196, Loss: 1.8023e-05
# [SMW-HODLR] Iter 197, Loss: 1.6216e-05
# [SMW-HODLR] Iter 198, Loss: 1.4596e-05
# [SMW-HODLR] Iter 199, Loss: 1.3136e-05
# [SMW-HODLR] Iter 200, Loss: 1.1821e-05
# [SMW-HODLR] Iter 201, Loss: 1.0642e-05
# [SMW-HODLR] Iter 202, Loss: 9.5777e-06
# [SMW-HODLR] Iter 203, Loss: 8.6197e-06
# [SMW-HODLR] Iter 204, Loss: 7.7565e-06
# [SMW-HODLR] Iter 205, Loss: 6.9821e-06
# [SMW-HODLR] Iter 206, Loss: 6.2852e-06
# [SMW-HODLR] Iter 207, Loss: 5.6582e-06
# [SMW-HODLR] Iter 208, Loss: 5.0921e-06
# [SMW-HODLR] Iter 209, Loss: 4.5822e-06
# [SMW-HODLR] Iter 210, Loss: 4.1233e-06
# [SMW-HODLR] Iter 211, Loss: 3.7113e-06
# [SMW-HODLR] Iter 212, Loss: 3.3398e-06
# [SMW-HODLR] Iter 213, Loss: 3.0054e-06
# [SMW-HODLR] Iter 214, Loss: 2.7055e-06
# [SMW-HODLR] Iter 215, Loss: 2.4357e-06
# [SMW-HODLR] Iter 216, Loss: 2.1920e-06
# [SMW-HODLR] Iter 217, Loss: 1.9725e-06
# [SMW-HODLR] Iter 218, Loss: 1.7750e-06
# [SMW-HODLR] Iter 219, Loss: 1.5974e-06
# [SMW-HODLR] Iter 220, Loss: 1.4376e-06
# [SMW-HODLR] Iter 221, Loss: 1.2943e-06
# [SMW-HODLR] Iter 222, Loss: 1.1647e-06
# [SMW-HODLR] Iter 223, Loss: 1.0485e-06
# [SMW-HODLR] Iter 224, Loss: 9.4362e-07
# [SMW-HODLR] Iter 225, Loss: 8.4970e-07
# [SMW-HODLR] Iter 226, Loss: 7.6480e-07
# [SMW-HODLR] Iter 227, Loss: 6.8827e-07
# [SMW-HODLR] Iter 228, Loss: 6.1940e-07
# [SMW-HODLR] Iter 229, Loss: 5.5746e-07
# [SMW-HODLR] Iter 230, Loss: 5.0168e-07
# [SMW-HODLR] Iter 231, Loss: 4.5146e-07
# [SMW-HODLR] Iter 232, Loss: 4.0627e-07
# [SMW-HODLR] Iter 233, Loss: 3.6566e-07
# [SMW-HODLR] Iter 234, Loss: 3.2909e-07
# [SMW-HODLR] Iter 235, Loss: 2.9624e-07
# [SMW-HODLR] Iter 236, Loss: 2.6659e-07
# [SMW-HODLR] Iter 237, Loss: 2.3994e-07
# [SMW-HODLR] Iter 238, Loss: 2.1590e-07
# [SMW-HODLR] Iter 239, Loss: 1.9431e-07
# [SMW-HODLR] Iter 240, Loss: 1.7487e-07
# [SMW-HODLR] Iter 241, Loss: 1.5740e-07
# [SMW-HODLR] Iter 242, Loss: 1.4166e-07
# [SMW-HODLR] Iter 243, Loss: 1.2748e-07
# [SMW-HODLR] Iter 244, Loss: 1.1474e-07
# [SMW-HODLR] Iter 245, Loss: 1.0325e-07
# [SMW-HODLR] Iter 246, Loss: 9.2922e-08
# [SMW-HODLR] Iter 247, Loss: 8.3616e-08
# [SMW-HODLR] Iter 248, Loss: 7.5240e-08
# [SMW-HODLR] Iter 249, Loss: 6.7707e-08
# [SMW-HODLR] Iter 250, Loss: 6.0929e-08
# [SMW-HODLR] Iter 251, Loss: 5.4826e-08
# [SMW-HODLR] Iter 252, Loss: 4.9344e-08
# [SMW-HODLR] Iter 253, Loss: 4.4421e-08
# [SMW-HODLR] Iter 254, Loss: 3.9983e-08
# [SMW-HODLR] Iter 255, Loss: 3.5980e-08
# [SMW-HODLR] Iter 256, Loss: 3.2394e-08
# [SMW-HODLR] Iter 257, Loss: 2.9159e-08
# [SMW-HODLR] Iter 258, Loss: 2.6242e-08
# [SMW-HODLR] Iter 259, Loss: 2.3622e-08
# [SMW-HODLR] Iter 260, Loss: 2.1254e-08
# [SMW-HODLR] Iter 261, Loss: 1.9127e-08
# [SMW-HODLR] Iter 262, Loss: 1.7209e-08
# [SMW-HODLR] Iter 263, Loss: 1.5484e-08
# [SMW-HODLR] Iter 264, Loss: 1.3932e-08
# [SMW-HODLR] Iter 265, Loss: 1.2542e-08
# [SMW-HODLR] Iter 266, Loss: 1.1291e-08
# [SMW-HODLR] Iter 267, Loss: 1.0166e-08
# [SMW-HODLR] Iter 268, Loss: 9.1501e-09
# [SMW-HODLR] Iter 269, Loss: 8.2331e-09
# [SMW-HODLR] Iter 270, Loss: 7.4124e-09
# [SMW-HODLR] Iter 271, Loss: 6.6701e-09
# [SMW-HODLR] Iter 272, Loss: 5.9993e-09
# [SMW-HODLR] Iter 273, Loss: 5.4003e-09
# [SMW-HODLR] Iter 274, Loss: 4.8583e-09
# [SMW-HODLR] Iter 275, Loss: 4.3768e-09
# [SMW-HODLR] Iter 276, Loss: 3.9351e-09
# [SMW-HODLR] Iter 277, Loss: 3.5401e-09
# [SMW-HODLR] Iter 278, Loss: 3.1863e-09
# [SMW-HODLR] Iter 279, Loss: 2.8703e-09
# [SMW-HODLR] Iter 280, Loss: 2.5787e-09
# [SMW-HODLR] Iter 281, Loss: 2.3166e-09
# [SMW-HODLR] Iter 282, Loss: 2.0880e-09
# [SMW-HODLR] Iter 283, Loss: 1.8813e-09
# [SMW-HODLR] Iter 284, Loss: 1.6849e-09
# [SMW-HODLR] Iter 285, Loss: 1.5194e-09
# [SMW-HODLR] Iter 286, Loss: 1.3580e-09
# [SMW-HODLR] Iter 287, Loss: 1.2221e-09
# [SMW-HODLR] Iter 288, Loss: 1.1066e-09
# [SMW-HODLR] Iter 289, Loss: 9.9378e-10
# [SMW-HODLR] Iter 290, Loss: 8.9297e-10
# [SMW-HODLR] Iter 291, Loss: 8.0797e-10
# [SMW-HODLR] Iter 292, Loss: 7.2269e-10
# [SMW-HODLR] Iter 293, Loss: 6.5297e-10
# [SMW-HODLR] Iter 294, Loss: 5.8727e-10
# [SMW-HODLR] Iter 295, Loss: 5.2803e-10
# [SMW-HODLR] Iter 296, Loss: 4.7514e-10
# [SMW-HODLR] Iter 297, Loss: 4.2865e-10
# [SMW-HODLR] Iter 298, Loss: 3.8776e-10
# [SMW-HODLR] Iter 299, Loss: 3.4370e-10

# %%
# True solution (depends on your PDE choice)
u_true = torch.sin(torch.pi * x)

# Predicted solution from model
with torch.no_grad():
    c = model_smw()          # use trained model
    u_pred = Phi @ c

# Move to numpy
x_np = x.detach().cpu().numpy()
u_true_np = u_true.detach().cpu().numpy()
u_pred_np = u_pred.detach().cpu().numpy()

# Plot: True vs Predicted
plt.figure(figsize=(6,4))
plt.plot(x_np, u_true_np, label="True Solution")
plt.plot(x_np, u_pred_np, '--', label="Spectral PINN")

plt.legend()
plt.title("Solution Comparison")
plt.xlabel("x")
plt.ylabel("u(x)")
plt.grid()
plt.show()

# %%
# Absolute error
error = torch.abs(u_pred - u_true)
error_np = error.detach().cpu().numpy()

plt.figure(figsize=(6,4))
plt.plot(x_np, error_np)

plt.title("Absolute Error |u_pred - u_true|")
plt.xlabel("x")
plt.ylabel("Error")
plt.grid()
plt.show()

# %%
# Relative L2 error
l2_error = torch.norm(u_pred - u_true) / torch.norm(u_true)

print("Relative L2 Error:", l2_error.item())
# Out:
# Relative L2 Error: 4.028087651794511e-14

# %% [markdown]
# ## refactoring the method 1

# %%
def setup_problem(N):
    """
    Build A, Phi, f for given N
    """
    
    K = 20  # important scaling
    
    # Grid
    x, D = chebyshev_diff_matrix(N)
    
    # Operator
    A = build_A(D, bc_weight=10.0)
    
    # Basis
    Phi = chebyshev_basis(x, K)
    
    # Correct RHS
    f = (torch.pi**2) * torch.sin(torch.pi * x)
    f = torch.cat([f, torch.zeros(2)])
    
    return x, A, Phi, f, K

# %%
def build_hodlr(A, p=16):
    
    A_np = A.detach().cpu().numpy()
    
    def A_block(row_idx, col_idx):
        return A_np[np.ix_(row_idx, col_idx)]
    
    max_level = int(np.ceil(np.log2(max(A.shape) / p)))  # adjust leaf size as needed
    
    H = RectangularHODLR(
        n_rows=A.shape[0],
        n_cols=A.shape[1],
        block_fn=A_block,
        p=p,
        max_level=max_level
    )
    
    return H

# %%
def train_method_1(model, H, Phi, A, f, steps=20, lam=1e-3):
    
    losses = []
    
    for i in range(steps):
        
        # B
        B = build_B(model)
        
        # Residual
        r, u, c = compute_residual(model, A, Phi, f)
        
        loss = torch.norm(r)
        losses.append(loss.item())
        
        # AΦ (HODLR)
        APhi = compute_A_Phi_hodlr(H, Phi)
        
        # G
        G = compute_G_from_APhi(APhi)
        
        # RHS
        g = compute_rhs_hodlr(H, Phi, B, r)
        
        # μ (correct version)
        mu = lam * torch.max(torch.diag(G))
        
        # SMW solve
        delta_theta = solve_smw(G, B, g, mu)
        
        # Update
        apply_update(model, delta_theta, lr=0.1)
    
    return losses, model

# %%
def run_method_1(N, steps=200):
    
    # Setup
    x, A, Phi, f, K = setup_problem(N)
    
    # Model
    model = CoeffNet(K)
    
    # Build HODLR
    t0 = time.time()
    H = build_hodlr(A)
    t1 = time.time()
    
    hodlr_time = t1 - t0
    
    # Train
    t2 = time.time()
    losses, model = train_method_1(model, H, Phi, A, f, steps=steps)
    t3 = time.time()
    
    train_time = t3 - t2
    
    # Prediction
    with torch.no_grad():
        c = model()
        u_pred = Phi @ c
        u_true = torch.sin(torch.pi * x)
    
    # Error
    l2_error = torch.norm(u_pred - u_true) / torch.norm(u_true)
    
    return {
        "N": N,
        "hodlr_time": hodlr_time,
        "train_time": train_time,
        "total_time": hodlr_time + train_time,
        "l2_error": l2_error.item(),
        "losses": losses
    }

# %%
result = run_method_1(20, steps=10)

print(result)
# Out:
# {'N': 20, 'hodlr_time': 7.224082946777344e-05, 'train_time': 0.01568007469177246, 'total_time': 0.015752315521240234, 'l2_error': 1.6750525784393835, 'losses': [34084.89237432149, 30688.30831436876, 27628.915178832754, 24873.515529640063, 22392.135242018674, 20157.713778043715, 18145.825982999875, 16334.431067749685, 14703.645396617301, 13235.536419263784]}

# %% [markdown]
# # Method 2: LSQR (Matrix-Free Gauss–Newton)
#
# We solve:
#
#     (J^T J + μI) Δθ = -J^T r
#
# by converting to least squares:
#
#     min ||Q Δθ - b||^2
#
# where:
#
#     Q = [J; sqrt(μ) I]
#
# We NEVER form J explicitly.
#
# We only implement:
#
#     y = Qx
#     z = Q^T y
#
# using:
#     J = A Φ B
#
# This enables matrix-free optimization.

# %%
def forward_Q(H, Phi, B, x, mu):
    """
    Compute:
        y = Qx
    
    where:
        Q = [ J ; sqrt(mu) I ]
        J = A Φ B
    
    Inputs:
        x  : (P,)
        B  : (K, P)
        Phi: (N+1, K)
        H  : HODLR (for A)
        mu : scalar
    
    Output:
        y  : (N+3 + P,)
    """
    
    # Step 1: Bx
    Bx = B @ x                  # (K,)
    
    # Step 2: Φ(Bx)
    PhiBx = Phi @ Bx            # (N+1,)
    
    # Step 3: A(Φ(Bx)) using HODLR
    A_PhiBx = hodlr_matvec(H, PhiBx)   # (N+3,)
    
    # Step 4: sqrt(mu) * x
    reg = (mu ** 0.5) * x           # (P,)
    
    # Step 5: concatenate
    y = torch.cat([A_PhiBx, reg])
    
    return y

# %%
P = sum(p.numel() for p in model_smw.parameters())
x_test = torch.randn(P)

B = build_B(model_smw)
mu = 1e-3

y = forward_Q(H, Phi, B, x_test, mu)

print(y.shape)
# Out:
# torch.Size([291])

# %%
def adjoint_Q(H, Phi, B, y, mu):
    """
    Compute:
        z = Q^T y
    
    where:
        Q^T y = B^T (Φ^T (A^T y1)) + sqrt(mu) y2
    
    Inputs:
        y  : (N+3 + P,)
    
    Output:
        z  : (P,)
    """
    
    Np3 = H.n_rows   # = N+3
    
    # Step 1: split y
    y1 = y[:Np3]     # (N+3,)
    y2 = y[Np3:]     # (P,)
    
    # Step 2: A^T y1 (HODLR)
    At_y1 = hodlr_matvec_transpose(H, y1)   # (N+1,)
    
    # Step 3: Φ^T (A^T y1)
    PhiT_At_y1 = Phi.T @ At_y1              # (K,)
    
    # Step 4: B^T (...)
    term1 = B.T @ PhiT_At_y1                # (P,)
    
    # Step 5: sqrt(mu) * y2
    term2 = (mu ** 0.5) * y2               # (P,)
    
    # Step 6: sum
    z = term1 + term2
    
    return z

# %%
y_test = torch.randn(H.n_rows + P)

z = adjoint_Q(H, Phi, B, y_test, mu)

print(z.shape)
# Out:
# torch.Size([268])

# %%
x_test = torch.randn(P)
y_test = torch.randn(H.n_rows + P)

lhs = torch.dot(forward_Q(H, Phi, B, x_test, mu), y_test)
rhs = torch.dot(x_test, adjoint_Q(H, Phi, B, y_test, mu))

print("Adjoint error:", abs(lhs - rhs).item())
# Out:
# Adjoint error: 5.820766091346741e-10

# %%
def lsqr_solver(H, Phi, B, r, mu, max_iter=20):
    """
    Solve:
        min ||Q Δθ - b||^2
    
    using LSQR
    
    Inputs:
        r  : residual (N+3,)
        mu : scalar
    
    Output:
        delta_theta : (P,)
    """
    
    # Build RHS vector b = [-r ; 0]
    P = B.shape[1]
    b = torch.cat([-r, torch.zeros(P)])
    
    # Initial guess
    x = torch.zeros(P)
    
    # --- LSQR Initialization ---
    u = b.clone()
    beta = torch.norm(u)
    u = u / beta
    
    v = adjoint_Q(H, Phi, B, u, mu)
    alpha = torch.norm(v)
    v = v / alpha
    
    w = v.clone()
    
    phi_bar = beta
    rho_bar = alpha
    
    # --- Iterations ---
    for i in range(max_iter):
        
        # Step 1: u = Qv - alpha u
        u = forward_Q(H, Phi, B, v, mu) - alpha * u
        beta = torch.norm(u)
        u = u / beta
        
        # Step 2: v = Q^T u - beta v
        v = adjoint_Q(H, Phi, B, u, mu) - beta * v
        alpha = torch.norm(v)
        v = v / alpha
        
        # Step 3: orthogonal transformation
        rho = torch.sqrt(rho_bar**2 + beta**2)
        c = rho_bar / rho
        s = beta / rho
        
        theta = s * alpha
        rho_bar = -c * alpha
        phi = c * phi_bar
        phi_bar = s * phi_bar
        
        # Step 4: update solution
        x = x + (phi / rho) * w
        w = v - (theta / rho) * w
    
    return x

# %%
def lsqr_solver(H, Phi, B, r, mu, max_iter=20):
    """
    Solve:
        min ||Q Δθ - b||^2
    
    using LSQR
    
    Inputs:
        r  : residual (N+3,)
        mu : scalar
    
    Output:
        delta_theta : (P,)
    """
    
    # Build RHS vector b = [-r ; 0]
    P = B.shape[1]
    b = torch.cat([-r, torch.zeros(P)])
    
    # Initial guess
    x = torch.zeros(P)
    
    # --- LSQR Initialization ---
    u = b.clone()
    beta = torch.norm(u)
    u = u / beta
    
    v = adjoint_Q(H, Phi, B, u, mu)
    alpha = torch.norm(v)
    v = v / alpha
    
    w = v.clone()
    
    phi_bar = beta
    rho_bar = alpha
    
    # --- Iterations ---
    for i in range(max_iter):
        
        # Step 1: u = Qv - alpha u
        u = forward_Q(H, Phi, B, v, mu) - alpha * u
        beta = torch.norm(u)
        u = u / beta
        
        # Step 2: v = Q^T u - beta v
        v = adjoint_Q(H, Phi, B, u, mu) - beta * v
        alpha = torch.norm(v)
        v = v / alpha
        
        # Step 3: orthogonal transformation
        rho = torch.sqrt(rho_bar**2 + beta**2)
        c = rho_bar / rho
        s = beta / rho
        
        theta = s * alpha
        rho_bar = -c * alpha
        phi = c * phi_bar
        phi_bar = s * phi_bar
        
        # Step 4: update solution
        x = x + (phi / rho) * w
        w = v - (theta / rho) * w
    
    return x

# %%
def train_method_2(model, H, Phi, A, f, steps=20, lam=1e-3, lsqr_iters=20):
    
    losses = []
    
    for i in range(steps):
        
        # Step 1: Build B
        B = build_B(model)
        
        # Step 2: Residual
        r, u, c = compute_residual(model, A, Phi, f)
        
        loss = torch.norm(r)
        losses.append(loss.item())
        
        # Step 3: μ (same logic as Method 1)
        APhi = compute_A_Phi_hodlr(H, Phi)
        G = compute_G_from_APhi(APhi)
        mu = lam * torch.max(torch.diag(G))
        
        # Step 4: Solve using LSQR
        delta_theta = lsqr_solver(H, Phi, B, r, mu, max_iter=lsqr_iters)
        
        # Step 5: Update
        apply_update(model, delta_theta, lr=0.1)
    
    return losses, model

# %%
def run_method_2(N, steps=20, lsqr_iters=20):
    
    # Setup
    x, A, Phi, f, K = setup_problem(N)
    
    # Model
    model = CoeffNet(K)
    
    # Build HODLR
    t0 = time.time()
    H = build_hodlr(A)
    t1 = time.time()
    
    hodlr_time = t1 - t0
    
    # Train
    t2 = time.time()
    losses, model = train_method_2(
        model, H, Phi, A, f,
        steps=steps,
        lsqr_iters=lsqr_iters
    )
    t3 = time.time()
    
    train_time = t3 - t2
    
    # Prediction
    with torch.no_grad():
        c = model()
        u_pred = Phi @ c
        u_true = torch.sin(torch.pi * x)
    
    # Error
    l2_error = torch.norm(u_pred - u_true) / torch.norm(u_true)
    
    return {
        "N": N,
        "hodlr_time": hodlr_time,
        "train_time": train_time,
        "total_time": hodlr_time + train_time,
        "l2_error": l2_error.item(),
        "losses": losses
    }

# %%
result2 = run_method_2(20, steps=10, lsqr_iters=10)

print(result2)
# Out:
# {'N': 20, 'hodlr_time': 4.9114227294921875e-05, 'train_time': 0.023637771606445312, 'total_time': 0.023686885833740234, 'l2_error': 1.69343983191866, 'losses': [38758.29535588737, 34904.906601705945, 31432.92839172462, 28304.918599177407, 25487.08066000713, 22948.903485191884, 20662.841111145994, 18604.026412375406, 16750.0141115981, 15080.549168600754]}

# %%
N_list_small = [4, 12, 20, 28, 36, 44, 52, 60]

results_m1 = []
results_m2 = []

for N in N_list_small:
    print(f"\nRunning N = {N}")
    
    res1 = run_method_1(N, steps=500)
    res2 = run_method_2(N, steps=500, lsqr_iters=100)
    
    results_m1.append(res1)
    results_m2.append(res2)
# Out:
# Running N = 4
#
# Running N = 12
#
# Running N = 20
#
# Running N = 28
#
# Running N = 36
#
# Running N = 44
#
# Running N = 52
#
# Running N = 60

# %%
N_vals = [r["N"] for r in results_m1]

time_m1 = [r["total_time"] for r in results_m1]
time_m2 = [r["total_time"] for r in results_m2]

plt.figure()
plt.plot(N_vals, time_m1, 'o-', label="Method 1 (SMW)")
plt.plot(N_vals, time_m2, 'o-', label="Method 2 (LSQR)")

plt.xlabel("N (Collocation Points)")
plt.ylabel("Time (seconds)")
plt.title("Time vs N (Small Scale)")
plt.legend()
plt.grid()
plt.show()

# %%
N_list_large = [100, 300, 500]   # avoid 10^4 for now

results_m1_large = []
results_m2_large = []

for N in N_list_large:
    print(f"\nRunning N = {N}")
    
    res1 = run_method_1(N, steps=500)
    res2 = run_method_2(N, steps=500, lsqr_iters=100)
    
    results_m1_large.append(res1)
    results_m2_large.append(res2)
# Out:
# Running N = 100
#
# Running N = 300
#
# Running N = 500

# %%
N_vals = [r["N"] for r in results_m1_large]

time_m1 = [r["total_time"] for r in results_m1_large]
time_m2 = [r["total_time"] for r in results_m2_large]

plt.figure()
plt.plot(N_vals, time_m1, 'o-', label="Method 1 (SMW)")
plt.plot(N_vals, time_m2, 'o-', label="Method 2 (LSQR)")

plt.xlabel("N (Collocation Points)")
plt.ylabel("Time (seconds)")
plt.title("Time vs N (Large Scale)")
plt.legend()
plt.grid()
plt.show()

# %%
def extract_metrics(results):
    N_vals = [r["N"] for r in results]
    times = [r["total_time"] for r in results]
    errors = [r["l2_error"] for r in results]
    
    return N_vals, times, errors

# %%
N1, time_m1, err_m1 = extract_metrics(results_m1)
N2, time_m2, err_m2 = extract_metrics(results_m2)

plt.figure(figsize=(6,4))

plt.plot(N1, time_m1, 'o-', label="Method 1 (SMW)")
plt.plot(N2, time_m2, 's-', label="Method 2 (LSQR)")

plt.xlabel("N (Collocation Points)")
plt.ylabel("Time (seconds)")
plt.title("Time vs N (Small Scale)")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6,4))

plt.plot(N1, err_m1, 'o-', label="Method 1 (SMW)")
plt.plot(N2, err_m2, 's-', label="Method 2 (LSQR)")

plt.yscale('log')

plt.xlabel("N")
plt.ylabel("Relative L2 Error")
plt.title("Error vs N")
plt.legend()
plt.grid()
plt.show()

# %%
N1L, time_m1L, err_m1L = extract_metrics(results_m1_large)
N2L, time_m2L, err_m2L = extract_metrics(results_m2_large)

plt.figure(figsize=(6,4))

plt.plot(N1L, time_m1L, 'o-', label="Method 1 (SMW)")
plt.plot(N2L, time_m2L, 's-', label="Method 2 (LSQR)")

plt.xlabel("N (Collocation Points)")
plt.ylabel("Time (seconds)")
plt.title("Time vs N (Large Scale)")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6,4))

# pick one N (e.g., last run)
plt.plot(results_m1[-1]["losses"], label="Method 1 (SMW)")
plt.plot(results_m2[-1]["losses"], label="Method 2 (LSQR)")

plt.yscale('log')

plt.xlabel("Iteration")
plt.ylabel("Residual Norm")
plt.title("Convergence Comparison")
plt.legend()
plt.grid()
plt.show()
